# %% [markdown]
# <a href="https://colab.research.google.com/github/TheoLam00/TheoLam00.github.io/blob/main/project/cbp/demVote%26Cbp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
cbp2020 = pd.read_csv('https://raw.githubusercontent.com/TheoLam00/TheoLam00.github.io/refs/heads/main/project/cbp/cbp2020.csv')
cbp2016 = pd.read_csv('https://raw.githubusercontent.com/TheoLam00/TheoLam00.github.io/refs/heads/main/project/cbp/cbp2016.csv')
cbp2012 = pd.read_csv('https://raw.githubusercontent.com/TheoLam00/TheoLam00.github.io/refs/heads/main/project/cbp/cbp2012.csv')

#merge into cbp
cbp2020['year'] = 2020
cbp2016['year'] = 2016
cbp2012['year'] = 2012
cbp = pd.concat([cbp2020,cbp2016,cbp2012])

vote = pd.read_csv('https://raw.githubusercontent.com/TheoLam00/TheoLam00.github.io/refs/heads/main/project/swingState/pVoteDemRatio-long.csv')
cbp.drop(columns=['Unnamed: 0'], inplace=True)
vote.drop(columns=['Unnamed: 0'], inplace=True)

# %%
cbp
# Out:
#       state  naics  num_employees  annual_payroll  year
# 0         1     11           6380          307110  2020
# 1         1     21           6022          449620  2020
# 2         1     22          15111         1733217  2020
# 3         1     23          92712         5214537  2020
# 4         1     31         264687        14263340  2020
# ...     ...    ...            ...             ...   ...
# 1014     56     62          31308         1357505  2012
# 1015     56     71           4412           86796  2012
# 1016     56     72          27164          484108  2012
# 1017     56     81           8802          262607  2012
# 1018     56     99             40            1178  2012
#
# [3057 rows x 5 columns]

# %%
#map state id and naics
naics_name = {'11':'Agriculture, Forestry, Fishing and Hunting','21':'Mining, Quarrying, and Oil and Gas Extraction','22':'Utilities','23':'Construction','31':'Manufacturing','42':'Wholesale Trade','44':'Retail Trade','48':'Transportation and Warehousing','51':'Information','52':'Finance and Insurance','53':'Real Estate and Rental and Leasing','54':'Professional, Scientific, and Technical Services','55':'Management of Companies and Enterprises','56':'Administrative and Support and Waste Management and Remediation Services','61':'Educational Services','62':'Health Care and Social Assistance','71':'Arts, Entertainment, and Recreation','72':'Accommodation and Food Services','81':'Other Services (except Public Administration)','99':'Industries not classified'}
state = {'1':'Alabama','2':'Alaska','4':'Arizona','5':'Arkansas','6':'California','8':'Colorado','9':'Connecticut','10':'Delaware','11':'District of Columbia','12':'Florida','13':'Georgia','15':'Hawaii','16':'Idaho','17':'Illinois','18':'Indiana','19':'Iowa','20':'Kansas','21':'Kentucky','22':'Louisiana','23':'Maine','24':'Maryland','25':'Massachusetts','26':'Michigan','27':'Minnesota','28':'Mississippi','29':'Missouri','30':'Montana','31':'Nebraska','32':'Nevada','33':'New Hampshire','34':'New Jersey','35':'New Mexico','36':'New York','37':'North Carolina','38':'North Dakota','39':'Ohio','40':'Oklahoma','41':'Oregon','42':'Pennsylvania','72':'Puerto Rico','44':'Rhode Island','45':'South Carolina','46':'South Dakota','47':'Tennessee','48':'Texas','49':'Utah','50':'Vermont','51':'Virginia','78':'Virgin Islands','53':'Washington','54':'West Virginia','55':'Wisconsin','56':'Wyoming'}

# %%
#change ids to string
cbp['state'] = cbp['state'].astype(str)
cbp['naics'] = cbp['naics'].astype(str)
cbp = cbp.replace({'state':state})
cbp = cbp.replace({'naics':naics_name})

# %%
#filter vote data to match cbp data
vote = vote[(vote['year']==2020)|(vote['year']==2016)|(vote['year']==2012)]

# %%
cbp
# Out:
#         state                                          naics  num_employees  \
# 0     Alabama     Agriculture, Forestry, Fishing and Hunting           6380
# 1     Alabama  Mining, Quarrying, and Oil and Gas Extraction           6022
# 2     Alabama                                      Utilities          15111
# 3     Alabama                                   Construction          92712
# 4     Alabama                                  Manufacturing         264687
# ...       ...                                            ...            ...
# 1014  Wyoming              Health Care and Social Assistance          31308
# 1015  Wyoming            Arts, Entertainment, and Recreation           4412
# 1016  Wyoming                Accommodation and Food Services          27164
# 1017  Wyoming  Other Services (except Public Administration)           8802
# 1018  Wyoming                      Industries not classified             40
#
#       annual_payroll  year
# 0             307110  2020
# ...

# %%
#joint two data
df = pd.merge(cbp, vote, on=['state','year'])

# %%
df
# Out:
#         state                                          naics  num_employees  \
# 0     Alabama     Agriculture, Forestry, Fishing and Hunting           6380
# 1     Alabama  Mining, Quarrying, and Oil and Gas Extraction           6022
# 2     Alabama                                      Utilities          15111
# 3     Alabama                                   Construction          92712
# 4     Alabama                                  Manufacturing         264687
# ...       ...                                            ...            ...
# 3052  Wyoming              Health Care and Social Assistance          31308
# 3053  Wyoming            Arts, Entertainment, and Recreation           4412
# 3054  Wyoming                Accommodation and Food Services          27164
# 3055  Wyoming  Other Services (except Public Administration)           8802
# 3056  Wyoming                      Industries not classified             40
#
#       annual_payroll  year  demRatio
# ...

# %%
#add total pop
pop = pd.read_csv('https://raw.githubusercontent.com/TheoLam00/TheoLam00.github.io/refs/heads/main/project/manufactoring/Fred-Population.csv')
pop = pop.drop(columns=['Unnamed: 0'])
pop
# Out:
#             date    value    state
# 0     1950-01-01  135.000   Alaska
# 1     1951-01-01  158.000   Alaska
# 2     1952-01-01  189.000   Alaska
# 3     1953-01-01  205.000   Alaska
# 4     1954-01-01  215.000   Alaska
# ...          ...      ...      ...
# 6219  2019-01-01  580.116  Wyoming
# 6220  2020-01-01  577.664  Wyoming
# 6221  2021-01-01  579.548  Wyoming
# 6222  2022-01-01  581.629  Wyoming
# 6223  2023-01-01  584.057  Wyoming
#
# [6224 rows x 3 columns]

# %%
pop['date'] = pop['date'].str.slice(0,4)
pop = pop.rename(columns={'date':'year'})
pop['year'] = pop['year'].astype(int)
pop = pop[(pop['year']==2020)|(pop['year']==2016)|(pop['year']==2012)]

# %%
df2 = pd.merge(df, pop, on=['state','year'])
df2 = df2.rename(columns={'value':'total_pop'})

# %%
from google.colab import files
df2.to_csv('voteCbp.csv')
files.download('voteCbp.csv')
