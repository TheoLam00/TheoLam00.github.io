# %% [markdown]
# <a href="https://colab.research.google.com/github/TheoLam00/TheoLam00.github.io/blob/main/project/spending/spending.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import zipfile as zp
import requests
from io import BytesIO

# %%
#select data of election year
year = [2008,2012,2016,2020]
candidate = [[2008,['Obama, Barack','McCain, John']],[2012,['Obama, Barack','Romney, Mitt']],[2016,['Clinton, Hillary','Trump, Donald J.']],[2020,['Biden, Joe','Trump, Donald J.']]]

# %%
#read data from https://www.fec.gov/data/candidates/president/presidential-map/
url = 'https://www.fec.gov/files/bulk-downloads/Presidential_Map/2020/P00000001/P00000001D-ALL.zip'
data = requests.get(url)
file = zp.ZipFile(BytesIO(data.content))
df = pd.read_csv(file.open('P00000001D-ALL.csv'))
# Out:
# <ipython-input-2-84b6a6cf7525>:5: DtypeWarning: Columns (8,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file.open('P00000001D-ALL.csv'))

# %%
df
# Out:
#              cmte_id            cand_id                cand_nm  recipient_nm  \
# C00285254  P00013649  Sanford, Marshall       GODADDY.COM, LLC          5.44
# C00285254  P00013649  Sanford, Marshall       GODADDY.COM, LLC         10.89
# C00285254  P00013649  Sanford, Marshall       GODADDY.COM, LLC         65.32
# C00285254  P00013649  Sanford, Marshall       GODADDY.COM, LLC          5.44
# C00285254  P00013649  Sanford, Marshall       GODADDY.COM, LLC         10.88
# ...              ...                ...                    ...           ...
# C00751701  P00016741        West, Kanye  FIRST BANK OF WYOMING        100.00
# C00751701  P00016741        West, Kanye                SHOPIFY       8631.45
# C00751701  P00016741        West, Kanye                SHOPIFY       6354.18
# C00751701  P00016741        West, Kanye                SHOPIFY      60689.44
# C00751701  P00016741        West, Kanye                SHOPIFY       8834.26
#
#             disb_amt     disb_dt recipient_city recipient_st  \
# C00285254  21-OCT-19  SCOTTSDALE             AZ    852606993
# C00285254  23-OCT-19  SCOTTSDALE             AZ    852606993
# C00285254  25-OCT-19  SCOTTSDALE             AZ    852606993
# C00285254  17-NOV-19  SCOTTSDALE             AZ    852606993
# C00285254  17-DEC-19  SCOTTSDALE             AZ    852606993
# ...              ...         ...            ...          ...
# C00751701  21-AUG-20        CODY             WY        82414
# C00751701  30-NOV-20     ONTARIO             ZZ       K2P1L4
# C00751701  31-DEC-20     ONTARIO             ZZ       K2P1L4
# C00751701  13-OCT-20     ONTARIO             ZZ       K2P1L4
# C00751701  14-OCT-20     ONTARIO             ZZ       K2P1L4
#
#                          recipient_zip disb_desc memo_cd memo_text  form_tp  \
# C00285254                EMAIL SERVICE         X     NaN      SB23  1377011
# C00285254                EMAIL SERVICE         X     NaN      SB23  1377011
# C00285254                EMAIL SERVICE         X     NaN      SB23  1377011
# C00285254                EMAIL SERVICE         X     NaN      SB23  1377011
# C00285254                EMAIL SERVICE         X     NaN      SB23  1377011
# ...                                ...       ...     ...       ...      ...
# C00751701                     BANK FEE       NaN     NaN      SB23  1436461
# C00751701  CREDIT CARD PROCESSING FEES       NaN     NaN      SB23  1497668
# C00751701  CREDIT CARD PROCESSING FEES       NaN     NaN      SB23  1497668
# C00751701   CREDIT CARD PROCESSING FEE       NaN     NaN      SB23  1463864
# C00751701  CREDIT CARD PROCESSING FEES       NaN     NaN      SB23  1463864
#
#                        file_num tran_id  election_tp
# C00285254  B54FF81DC39E24F02B7F   P2020          NaN
# C00285254  B40AA74EF5DAD44EEB76   P2020          NaN
# C00285254  BB29694C590044886985   P2020          NaN
# C00285254  B4E3C9F1450874913B82   P2020          NaN
# C00285254  B99AA75CF0CEE4F83911   P2020          NaN
# ...                         ...     ...          ...
# C00751701             SB23.4170   G2020          NaN
# C00751701            SB23.32018     NaN          NaN
# C00751701            SB23.32010     NaN          NaN
# C00751701            SB23.16861     NaN          NaN
# C00751701            SB23.16978     NaN          NaN
#
# [517992 rows x 16 columns]
