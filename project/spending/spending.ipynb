# %% [markdown]
# <a href="https://colab.research.google.com/github/TheoLam00/TheoLam00.github.io/blob/main/project/spending/spending.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import zipfile as zp
import requests
from io import BytesIO

# %%
#select data of election year
year = [2008,2012,2016,2020]
candidate = [['Obama, Barack','McCain, John S'],['Obama, Barack','Romney, Mitt'],['Clinton, Hillary Rodham','Trump, Donald J.'],['Biden, Joseph R Jr','Trump, Donald J.']]
allData = pd.DataFrame()

# %%
#read data from https://www.fec.gov/data/candidates/president/presidential-map/
for i in range(len(year)):
  url = 'https://www.fec.gov/files/bulk-downloads/Presidential_Map/{}/P00000001/P00000001D-ALL.zip'
  url = url.format(year[i])
  data = requests.get(url)
  file = zp.ZipFile(BytesIO(data.content))
  df = pd.read_csv(file.open('P00000001D-ALL.csv'))
  #filter the candidate from dem and rep
  df = df[(df['cand_id']==candidate[i][0])|(df['cand_id']==candidate[i][1])]
  df = df[['cand_id','recipient_city','recipient_nm']]
  df = df.groupby(['cand_id','recipient_city']).sum()
  df = df.reset_index()
  df = df.rename(columns={'recipient_nm':'spending'})
  df['year'] = year[i]
  #add to all data
  allData = pd.concat([allData, df])
# Out:
# <ipython-input-122-5f4d8b5bdcdc>:7: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file.open('P00000001D-ALL.csv'))
# <ipython-input-122-5f4d8b5bdcdc>:7: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file.open('P00000001D-ALL.csv'))
# <ipython-input-122-5f4d8b5bdcdc>:7: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file.open('P00000001D-ALL.csv'))
# <ipython-input-122-5f4d8b5bdcdc>:7: DtypeWarning: Columns (8,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file.open('P00000001D-ALL.csv'))

# %%
allData
# Out:
#               cand_id recipient_city     spending  year
# 0      McCain, John S             99      1991.21  2008
# 1      McCain, John S             AK    333762.32  2008
# 2      McCain, John S             AL   1325086.19  2008
# 3      McCain, John S             AR     29328.83  2008
# 4      McCain, John S             AZ  15497810.46  2008
# ..                ...            ...          ...   ...
# 102  Trump, Donald J.             WA    990269.50  2020
# 103  Trump, Donald J.             WI   2937454.76  2020
# 104  Trump, Donald J.             WV    154823.04  2020
# 105  Trump, Donald J.             WY     29361.84  2020
# 106  Trump, Donald J.             ZZ    111423.67  2020
#
# [485 rows x 4 columns]

# %%
allData = allData.rename(columns={'cand_id':'candidate','recipient_city':'state'})
states = { 'AL':'Alabama', 'AK':'Alaska', 'AZ':'Arizona', 'AR':'Arkansas', 'CA':'California', 'CO':'Colorado', 'CT':'Connecticut', 'DE':'Delaware', 'DC':'District of Columbia', 'FL':'Florida', 'GA':'Georgia', 'HI':'Hawaii', 'ID':'Idaho', 'IL':'Illinois', 'IN':'Indiana', 'IA':'Iowa', 'KS':'Kansas', 'KY':'Kentucky', 'LA':'Louisiana', 'ME':'Maine', 'MD':'Maryland', 'MA':'Massachusetts', 'MI':'Michigan', 'MN':'Minnesota', 'MS':'Mississippi', 'MO':'Missouri', 'MT':'Montana', 'NE':'Nebraska', 'NV':'Nevada', 'NH':'New Hampshire', 'NJ':'New Jersey', 'NM':'New Mexico', 'NY':'New York', 'NC':'North Carolina', 'ND':'North Dakota', 'OH':'Ohio', 'OK':'Oklahoma', 'OR':'Oregon', 'PA':'Pennsylvania', 'RI':'Rhode Island', 'SC':'South Carolina', 'SD':'South Dakota', 'TN':'Tennessee', 'TX':'Texas', 'UT':'Utah', 'VT':'Vermont', 'VA':'Virginia', 'WA':'Washington', 'WV':'West Virginia', 'WI':'Wisconsin', 'WY':'Wyoming'}
allData['state'] = allData['state'].map(states)
allData = allData.dropna()

# %%
allData
# Out:
#             candidate          state     spending  year
# 1      McCain, John S         Alaska    333762.32  2008
# 2      McCain, John S        Alabama   1325086.19  2008
# 3      McCain, John S       Arkansas     29328.83  2008
# 4      McCain, John S        Arizona  15497810.46  2008
# 5      McCain, John S     California   7326717.33  2008
# ..                ...            ...          ...   ...
# 101  Trump, Donald J.        Vermont      2300.00  2020
# 102  Trump, Donald J.     Washington    990269.50  2020
# 103  Trump, Donald J.      Wisconsin   2937454.76  2020
# 104  Trump, Donald J.  West Virginia    154823.04  2020
# 105  Trump, Donald J.        Wyoming     29361.84  2020
#
# [408 rows x 4 columns]

# %%
from google.colab import files
allData.to_csv('spending.csv')
files.download('spending.csv')
