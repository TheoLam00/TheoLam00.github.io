# %% [markdown]
# <a href="https://colab.research.google.com/github/TheoLam00/TheoLam00.github.io/blob/main/pVoteClean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
import csv
from google.colab import files

# %%
import io
url = "https://raw.githubusercontent.com/TheoLam00/TheoLam00.github.io/refs/heads/main/project/1976-2020-president.csv"
data = requests.get(url).content
data = pd.read_csv(io.StringIO(data.decode('utf-8')))

# %%
data = data[['year','state','candidatevotes','party_simplified']]

# %%
#choose the winner in each state in each election
data = data.loc[data.groupby(['year','state'])['candidatevotes'].idxmax()]

# %%
#long data to wide data for map graph
df = data.drop(columns=['candidatevotes'])
df = df.pivot(index='year', columns='state', values='party_simplified')

# %%
df
# Out:
# state     ALABAMA      ALASKA     ARIZONA    ARKANSAS  CALIFORNIA    COLORADO  \
# year
# 1976     DEMOCRAT  REPUBLICAN  REPUBLICAN    DEMOCRAT  REPUBLICAN  REPUBLICAN
# 1980   REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN
# 1984   REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN
# 1988   REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN
# 1992   REPUBLICAN  REPUBLICAN  REPUBLICAN    DEMOCRAT    DEMOCRAT    DEMOCRAT
# 1996   REPUBLICAN  REPUBLICAN    DEMOCRAT    DEMOCRAT    DEMOCRAT  REPUBLICAN
# 2000   REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN    DEMOCRAT  REPUBLICAN
# 2004   REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN    DEMOCRAT  REPUBLICAN
# 2008   REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN    DEMOCRAT    DEMOCRAT
# 2012   REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN    DEMOCRAT    DEMOCRAT
# 2016   REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN    DEMOCRAT    DEMOCRAT
# 2020   REPUBLICAN  REPUBLICAN    DEMOCRAT  REPUBLICAN    DEMOCRAT    DEMOCRAT
#
# state CONNECTICUT    DELAWARE DISTRICT OF COLUMBIA     FLORIDA  ...  \
# year                                                            ...
# 1976   REPUBLICAN    DEMOCRAT             DEMOCRAT    DEMOCRAT  ...
# 1980   REPUBLICAN  REPUBLICAN             DEMOCRAT  REPUBLICAN  ...
# 1984   REPUBLICAN  REPUBLICAN             DEMOCRAT  REPUBLICAN  ...
# 1988   REPUBLICAN  REPUBLICAN             DEMOCRAT  REPUBLICAN  ...
# 1992     DEMOCRAT    DEMOCRAT             DEMOCRAT  REPUBLICAN  ...
# 1996     DEMOCRAT    DEMOCRAT             DEMOCRAT    DEMOCRAT  ...
# 2000     DEMOCRAT    DEMOCRAT             DEMOCRAT  REPUBLICAN  ...
# 2004     DEMOCRAT    DEMOCRAT             DEMOCRAT  REPUBLICAN  ...
# 2008     DEMOCRAT    DEMOCRAT             DEMOCRAT    DEMOCRAT  ...
# 2012     DEMOCRAT    DEMOCRAT             DEMOCRAT    DEMOCRAT  ...
# 2016     DEMOCRAT    DEMOCRAT             DEMOCRAT  REPUBLICAN  ...
# 2020     DEMOCRAT    DEMOCRAT             DEMOCRAT  REPUBLICAN  ...
#
# state SOUTH DAKOTA   TENNESSEE       TEXAS        UTAH     VERMONT  \
# year
# 1976    REPUBLICAN    DEMOCRAT    DEMOCRAT  REPUBLICAN  REPUBLICAN
# 1980    REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN
# 1984    REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN
# 1988    REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN
# 1992    REPUBLICAN    DEMOCRAT  REPUBLICAN  REPUBLICAN    DEMOCRAT
# 1996    REPUBLICAN    DEMOCRAT  REPUBLICAN  REPUBLICAN    DEMOCRAT
# 2000    REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN    DEMOCRAT
# 2004    REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN    DEMOCRAT
# 2008    REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN    DEMOCRAT
# 2012    REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN    DEMOCRAT
# 2016    REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN    DEMOCRAT
# 2020    REPUBLICAN  REPUBLICAN  REPUBLICAN  REPUBLICAN    DEMOCRAT
#
# state    VIRGINIA  WASHINGTON WEST VIRGINIA   WISCONSIN     WYOMING
# year
# 1976   REPUBLICAN  REPUBLICAN      DEMOCRAT    DEMOCRAT  REPUBLICAN
# 1980   REPUBLICAN  REPUBLICAN      DEMOCRAT  REPUBLICAN  REPUBLICAN
# 1984   REPUBLICAN  REPUBLICAN    REPUBLICAN  REPUBLICAN  REPUBLICAN
# 1988   REPUBLICAN    DEMOCRAT      DEMOCRAT    DEMOCRAT  REPUBLICAN
# 1992   REPUBLICAN    DEMOCRAT      DEMOCRAT    DEMOCRAT  REPUBLICAN
# 1996   REPUBLICAN    DEMOCRAT      DEMOCRAT    DEMOCRAT  REPUBLICAN
# 2000   REPUBLICAN    DEMOCRAT    REPUBLICAN    DEMOCRAT  REPUBLICAN
# 2004   REPUBLICAN    DEMOCRAT    REPUBLICAN    DEMOCRAT  REPUBLICAN
# 2008     DEMOCRAT    DEMOCRAT    REPUBLICAN    DEMOCRAT  REPUBLICAN
# 2012     DEMOCRAT    DEMOCRAT    REPUBLICAN    DEMOCRAT  REPUBLICAN
# 2016     DEMOCRAT    DEMOCRAT    REPUBLICAN  REPUBLICAN  REPUBLICAN
# 2020     DEMOCRAT    DEMOCRAT    REPUBLICAN    DEMOCRAT  REPUBLICAN
#
# [12 rows x 51 columns]
